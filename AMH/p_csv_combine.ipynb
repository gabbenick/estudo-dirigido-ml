# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Todos os csvs na database
csv_files = [f for f in os.listdir('./database') if f.endswith('.csv')]

dfs = []

# Iteração em todos os csvs e transformando em df
for file in csv_files:
    file_path = os.path.join('./database', file)
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concat todos os dfs
df = pd.concat(dfs, ignore_index=True)

# Remoção manual de atributos irrelevantes para análise do movimento humano
df = df.drop(df.columns[0], axis=1)
df = df.drop(['EMG_right', 'EMG_left'], axis=1)

# Conversão do df em um único csv
df.to_csv('./csv/database.csv', index=False)

# %%
display(df.describe())

print(df.info())

print(df['activity'].unique())
# Out:
#        accelerometer_right_foot_x  accelerometer_right_foot_y  \
# count               361344.000000               361344.000000
# mean                -11055.767521                -5702.629043
# std                   9498.228396                 8390.446926
# min                 -32768.000000               -32768.000000
# 25%                 -10996.000000                -8016.000000
# 50%                  -8564.000000                -4936.000000
# 75%                  -7452.000000                -3092.000000
# max                  32767.000000                32767.000000
#
#        accelerometer_right_foot_z  gyroscope_right_foot_x  \
# count               361344.000000           361344.000000
# mean                 12464.439410              -70.050749
# std                   8507.084345             1060.367551
# min                 -32768.000000           -13292.000000
# 25%                  11520.000000             -108.000000
# ...
